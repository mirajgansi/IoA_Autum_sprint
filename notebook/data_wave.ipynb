# %%
import numpy as np
import pandas as pd
import fuzzywuzzy
from fuzzywuzzy import process
import charset_normalizer

# %%
waveMusic_Df= pd.read_csv('../data/DataWave_Music_Sprint_Dataset - DataWave_Music_Sprint_Dataset.csv')
waveMusic_Df.head()
# Out:
#   user_id  country  age gender subscription_type  \
# 0   U1403    Nepal   23      F            Premum
# 1   U1165    Nepal   63   male           Student
# 2   U1474      USA   45      F            Premum
# 3   U1478  Nigeria   16      F            Family
# 4   U1609    Ghana   29      M              Free
#
#    avg_listening_hours_per_week  total_songs_played skip_rate  \
# 0                          11.5                 510        5%
# 1                          11.3                 526        5%
# 2                           2.0                 476       30%
# 3                          12.1                 529       20%
# 4                           6.4                 477       0.2
#
#    satisfaction_score churned monthly_fee   join_date
# 0                 2.0       0        7.99  03/21/2024
# 1                 3.0       0           0  08/10/2023
# 2                 3.0       0        7.99  04/05/2022
# 3                 5.0     yes       12.99  12/16/2023
# ...

# %%
waveMusic_Df.isna().sum()
# Out:
# user_id                         10
# country                          0
# age                              0
# gender                          79
# subscription_type                0
# avg_listening_hours_per_week     0
# total_songs_played               0
# skip_rate                        0
# satisfaction_score              44
# churned                          0
# monthly_fee                     33
# join_date                        0
# dtype: int64

# %%
waveMusic_Df["user_id"].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 700    False
# 701    False
# 702    False
# 703    False
# 704    False
# Name: user_id, Length: 705, dtype: bool

# %%
missing= waveMusic_Df.isna().sum()
percentMissing= (waveMusic_Df.isna().sum()/len(waveMusic_Df))*100
missing_data = pd.DataFrame({'Missing data':missing, 'percentage %':percentMissing})
print(missing_data)
# Out:
#                               Missing data  percentage %
# user_id                                 10      1.418440
# country                                  0      0.000000
# age                                      0      0.000000
# gender                                  79     11.205674
# subscription_type                        0      0.000000
# avg_listening_hours_per_week             0      0.000000
# total_songs_played                       0      0.000000
# skip_rate                                0      0.000000
# satisfaction_score                      44      6.241135
# churned                                  0      0.000000
# monthly_fee                             33      4.680851
# join_date                                0      0.000000

# %%
waveMusic_Df = waveMusic_Df.dropna(subset='user_id')

# %%
waveMusic_Df[waveMusic_Df['gender'].isna()]
# Out:
#     user_id         country  age gender subscription_type  \
# 6     U1262         Nigeria   59    NaN              Free
# 19    U1107    South Africa   33    NaN            Premum
# 20    U1568         Nigeria   33    NaN            Premum
# 46    U1511         Nigeria   39    NaN              Free
# 48    U1281         Nigeria   25    NaN            Family
# ..      ...             ...  ...    ...               ...
# 670   U1330             IND   36    NaN            Family
# 675   U1549          Brazil   41    NaN            Studnt
# 677   U1137  United Kingdom   59    NaN               Fam
# 688   U1229              UK   34    NaN              Free
# 701   U1143             IND   14    NaN           Premium
#
#      avg_listening_hours_per_week  total_songs_played skip_rate  \
# 6                             7.4                 502       25%
# 19                           14.6                 512       30%
# 20                           11.0                 522       20%
# ...

# %%
waveMusic_Df.describe
# Out:
# <bound method NDFrame.describe of     user_id         country  age  gender subscription_type  \
# 0     U1403           Nepal   23       F            Premum
# 1     U1165           Nepal   63    male           Student
# 2     U1474             USA   45       F            Premum
# 3     U1478         Nigeria   16       F            Family
# 4     U1609           Ghana   29       M              Free
# ..      ...             ...  ...     ...               ...
# 700   U1584  United Kingdom   30    Male           Student
# 701   U1143             IND   14     NaN           Premium
# 702   U1524             IND   55    male           Premium
# 703   U1046           Kenya   48  Female              Free
# 704   U1022           Nepal   13  Female               Fam
#
#      avg_listening_hours_per_week  total_songs_played skip_rate  \
# 0                            11.5                 510        5%
# 1                            11.3                 526        5%
# ...

# %%
waveMusic_Df.head()
# Out:
#   user_id  country  age gender subscription_type  \
# 0   U1403    Nepal   23      F            Premum
# 1   U1165    Nepal   63   male           Student
# 2   U1474      USA   45      F            Premum
# 3   U1478  Nigeria   16      F            Family
# 4   U1609    Ghana   29      M              Free
#
#    avg_listening_hours_per_week  total_songs_played skip_rate  \
# 0                          11.5                 510        5%
# 1                          11.3                 526        5%
# 2                           2.0                 476       30%
# 3                          12.1                 529       20%
# 4                           6.4                 477       0.2
#
#    satisfaction_score churned monthly_fee   join_date
# 0                 2.0       0        7.99  03/21/2024
# 1                 3.0       0           0  08/10/2023
# 2                 3.0       0        7.99  04/05/2022
# 3                 5.0     yes       12.99  12/16/2023
# ...

# %%
waveMusic_country =waveMusic_Df['country'].unique()
waveMusic_country.sort()
waveMusic_country
# Out:
# array(['Brazil', 'Ghana', 'IND', 'India', 'Kenya', 'Nepal', 'Nigeria',
#        'South Africa', 'U.K.', 'UK', 'USA', 'United Kingdom'],
#       dtype=object)

# %%
waveMusic_Df.isna().sum()
# Out:
# user_id                          0
# country                          0
# age                              0
# gender                          79
# subscription_type                0
# avg_listening_hours_per_week     0
# total_songs_played               0
# skip_rate                        0
# satisfaction_score              44
# churned                          0
# monthly_fee                     33
# join_date                        0
# dtype: int64

# %%
waveMusic_Df['country']= waveMusic_Df['country'].str.lower().str.strip()

# %%
waveMusic_Df['country'] = waveMusic_Df['country'].replace('ind', 'india')

# %%
waveMusic_Df.head()
# Out:
#   user_id  country  age gender subscription_type  \
# 0   U1403    nepal   23      F            Premum
# 1   U1165    nepal   63   male           Student
# 2   U1474      usa   45      F            Premum
# 3   U1478  nigeria   16      F            Family
# 4   U1609    ghana   29      M              Free
#
#    avg_listening_hours_per_week  total_songs_played skip_rate  \
# 0                          11.5                 510        5%
# 1                          11.3                 526        5%
# 2                           2.0                 476       30%
# 3                          12.1                 529       20%
# 4                           6.4                 477       0.2
#
#    satisfaction_score churned monthly_fee   join_date
# 0                 2.0       0        7.99  03/21/2024
# 1                 3.0       0           0  08/10/2023
# 2                 3.0       0        7.99  04/05/2022
# 3                 5.0     yes       12.99  12/16/2023
# ...

# %%
waveMusic_Df['country'] = waveMusic_Df['country'].replace(('uk','u.k.'), 'united kingdom')

# %%
waveMusic_Df['country'].unique()
# Out:
# array(['nepal', 'usa', 'nigeria', 'ghana', 'united kingdom', 'india',
#        'kenya', 'south africa', 'brazil'], dtype=object)

# %%
waveMusic_gender =waveMusic_Df['gender'].unique()
waveMusic_gender
# Out:
# array(['F', 'male', 'M', 'female', nan, 'Male', 'Female', 'Other'],
#       dtype=object)

# %%
waveMusic_Df
# Out:
#     user_id         country  age  gender subscription_type  \
# 0     U1403           nepal   23       F            Premum
# 1     U1165           nepal   63    male           Student
# 2     U1474             usa   45       F            Premum
# 3     U1478         nigeria   16       F            Family
# 4     U1609           ghana   29       M              Free
# ..      ...             ...  ...     ...               ...
# 700   U1584  united kingdom   30    Male           Student
# 701   U1143           india   14     NaN           Premium
# 702   U1524           india   55    male           Premium
# 703   U1046           kenya   48  Female              Free
# 704   U1022           nepal   13  Female               Fam
#
#      avg_listening_hours_per_week  total_songs_played skip_rate  \
# 0                            11.5                 510        5%
# 1                            11.3                 526        5%
# ...

# %%
waveMusic_Df['gender'] = waveMusic_Df['gender'].replace(('male', 'M'),'Male')
waveMusic_Df['gender'] = waveMusic_Df['gender'].replace(('female', 'F'),'Female')

# %%
waveMusic_sub = waveMusic_Df['subscription_type'].unique()
print(waveMusic_sub)
# Out:
# ['Premum' 'Student' 'Family' 'Free' 'Premium' 'Studnt' 'Fam']

# %%
waveMusic_Df['subscription_type'] = waveMusic_Df['subscription_type'].replace({
    'Premum': 'Premium',
    'Studnt': 'Student',
    'Fam': 'Family'
})

# %%
waveMusic_Df['subscription_type'].head
# Out:
# <bound method NDFrame.head of 0      Premium
# 1      Student
# 2      Premium
# 3       Family
# 4         Free
#         ...
# 700    Student
# 701    Premium
# 702    Premium
# 703       Free
# 704     Family
# Name: subscription_type, Length: 695, dtype: object>

# %%
waveMusic_Df.head()
# Out:
#   user_id  country  age  gender subscription_type  \
# 0   U1403    nepal   23  Female           Premium
# 1   U1165    nepal   63    Male           Student
# 2   U1474      usa   45  Female           Premium
# 3   U1478  nigeria   16  Female            Family
# 4   U1609    ghana   29    Male              Free
#
#    avg_listening_hours_per_week  total_songs_played skip_rate  \
# 0                          11.5                 510        5%
# 1                          11.3                 526        5%
# 2                           2.0                 476       30%
# 3                          12.1                 529       20%
# 4                           6.4                 477       0.2
#
#    satisfaction_score churned monthly_fee   join_date
# 0                 2.0       0        7.99  03/21/2024
# 1                 3.0       0           0  08/10/2023
# 2                 3.0       0        7.99  04/05/2022
# 3                 5.0     yes       12.99  12/16/2023
# ...

# %%
waveMusic_churend= waveMusic_Df['churned'].unique()
waveMusic_churend
# Out:
# array(['0', 'yes', '1', 'no'], dtype=object)

# %%
waveMusic_Df['churned']= waveMusic_Df['churned'].replace({
  'yes':'1',
  'no':'0'  
})

# %%
waveMusic_Df['churned'] = pd.to_numeric(waveMusic_Df['churned'], errors='coerce')
print('churn yes and no data are replaced with 0 and 1 , tunred into numeric')
print('waveMusic unique values:',waveMusic_Df['churned'].unique())
# Out:
# churn yes and no data are replaced with 0 and 1 , tunred into numeric
# waveMusic unique values: [0 1]

# %%
waveMusic_Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 695 entries, 0 to 704
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   user_id                       695 non-null    object
#  1   country                       695 non-null    object
#  2   age                           695 non-null    int64
#  3   gender                        616 non-null    object
#  4   subscription_type             695 non-null    object
#  5   avg_listening_hours_per_week  695 non-null    float64
#  6   total_songs_played            695 non-null    int64
#  7   skip_rate                     695 non-null    object
#  8   satisfaction_score            651 non-null    float64
#  9   churned                       695 non-null    int64
#  10  monthly_fee                   662 non-null    object
#  11  join_date                     695 non-null    object
# dtypes: float64(2), int64(3), object(7)
# ...

# %%
print(waveMusic_Df['join_date'].head())
# Out:
# 0    03/21/2024
# 1    08/10/2023
# 2    04/05/2022
# 3    12/16/2023
# 4    03/28/2022
# Name: join_date, dtype: object

# %%
waveMusic_Df['join_date'].dtype
# Out:
# dtype('O')

# %%
waveMusic_Df['join_date']=pd.to_datetime(waveMusic_Df['join_date'],format="mixed",dayfirst=True, errors='coerce')

# %%
waveMusic_Df['join_date']=waveMusic_Df['join_date'].dt.strftime("%d/%m/%Y")

# %%
waveMusic_Df.head()
# Out:
#   user_id  country  age  gender subscription_type  \
# 0   U1403    nepal   23  Female           Premium
# 1   U1165    nepal   63    Male           Student
# 2   U1474      usa   45  Female           Premium
# 3   U1478  nigeria   16  Female            Family
# 4   U1609    ghana   29    Male              Free
#
#    avg_listening_hours_per_week  total_songs_played skip_rate  \
# 0                          11.5                 510        5%
# 1                          11.3                 526        5%
# 2                           2.0                 476       30%
# 3                          12.1                 529       20%
# 4                           6.4                 477       0.2
#
#    satisfaction_score  churned monthly_fee   join_date
# 0                 2.0        0        7.99  21/03/2024
# 1                 3.0        0           0  08/10/2023
# 2                 3.0        0        7.99  04/05/2022
# 3                 5.0        1       12.99  16/12/2023
# ...

# %%
skip_rate =waveMusic_Df['skip_rate'].unique()
skip_rate
# Out:
# array(['5%', '30%', '20%', '0.2', '25%', '15%', '10%', 'ten', '0.1'],
#       dtype=object)

# %%
waveMusic_Df['skip_rate']= waveMusic_Df['skip_rate'].replace({
    'ten': '10%'
})

# %%
waveMusic_Df['skip_rate']= waveMusic_Df['skip_rate'].astype(str).str.strip()

# %%
percent_mask = waveMusic_Df['skip_rate'].str.contains("%")

# %%
waveMusic_Df.loc[percent_mask,'skip_rate']= (waveMusic_Df.loc
                                             [percent_mask, 'skip_rate']
                                             .str.replace('%','',regex=False)
                                             .astype(float)/100)

# %%
waveMusic_Df.loc[~percent_mask, 'skip_rate']=(
    waveMusic_Df.loc[~percent_mask, 'skip_rate']
    .astype(float)
)

# %%
waveMusic_Df.head(10)
# Out:
#   user_id         country  age  gender subscription_type  \
# 0   U1403           nepal   23  Female           Premium
# 1   U1165           nepal   63    Male           Student
# 2   U1474             usa   45  Female           Premium
# 3   U1478         nigeria   16  Female            Family
# 4   U1609           ghana   29    Male              Free
# 5   U1691  united kingdom   16  Female           Student
# 6   U1262         nigeria   59     NaN              Free
# 7   U1490  united kingdom   57  Female           Premium
# 8   U1514           india   23  Female           Student
# 9   U1412             usa   41    Male           Premium
#
#    avg_listening_hours_per_week  total_songs_played skip_rate  \
# 0                          11.5                 510      0.05
# 1                          11.3                 526      0.05
# 2                           2.0                 476       0.3
# 3                          12.1                 529       0.2
# ...

# %%
fee = waveMusic_Df['monthly_fee'].unique()
fee
# Out:
# array(['7.99', '0', '12.99', '9.99', '5', '9.99 USD', nan], dtype=object)

# %%
waveMusic_Df['monthly_fee'] =(
    waveMusic_Df['monthly_fee'].astype(str)
    .str.replace('USD','', regex=False)
    .str.strip()
)

# %%
waveMusic_Df['monthly_fee']= pd.to_numeric(waveMusic_Df['monthly_fee'],errors='coerce')

# %%
waveMusic_Df.head(10)
# Out:
#   user_id         country  age  gender subscription_type  \
# 0   U1403           nepal   23  Female           Premium
# 1   U1165           nepal   63    Male           Student
# 2   U1474             usa   45  Female           Premium
# 3   U1478         nigeria   16  Female            Family
# 4   U1609           ghana   29    Male              Free
# 5   U1691  united kingdom   16  Female           Student
# 6   U1262         nigeria   59     NaN              Free
# 7   U1490  united kingdom   57  Female           Premium
# 8   U1514           india   23  Female           Student
# 9   U1412             usa   41    Male           Premium
#
#    avg_listening_hours_per_week  total_songs_played skip_rate  \
# 0                          11.5                 510      0.05
# 1                          11.3                 526      0.05
# 2                           2.0                 476       0.3
# 3                          12.1                 529       0.2
# ...

# %%
def fill_na_by_country(df, group_col, target_col):
    group_modes =(
        df.groupby(group_col)[target_col]
        .agg(lambda x:x.mode().iloc[0] if not x.mode().empty else None)
    )
    df[target_col]= df.apply(
        lambda row: group_modes[row[group_col]]
        if pd.isna(row[target_col]) else row[target_col],
        axis =1
    )
    return df

# %%
clean_waveMusic= fill_na_by_country(waveMusic_Df, 'country', 'gender')
clean_waveMusic['gender'].head(10)
# Out:
# 0    Female
# 1      Male
# 2    Female
# 3    Female
# 4      Male
# 5    Female
# 6      Male
# 7    Female
# 8    Female
# 9      Male
# Name: gender, dtype: object

# %%
clean_waveMusic.isna().sum()
# Out:
# user_id                          0
# country                          0
# age                              0
# gender                           0
# subscription_type                0
# avg_listening_hours_per_week     0
# total_songs_played               0
# skip_rate                        0
# satisfaction_score              44
# churned                          0
# monthly_fee                     33
# join_date                        0
# dtype: int64

# %%
waveMusic_Df.head()
# Out:
#   user_id  country  age  gender subscription_type  \
# 0   U1403    nepal   23  Female           Premium
# 1   U1165    nepal   63    Male           Student
# 2   U1474      usa   45  Female           Premium
# 3   U1478  nigeria   16  Female            Family
# 4   U1609    ghana   29    Male              Free
#
#    avg_listening_hours_per_week  total_songs_played skip_rate  \
# 0                          11.5                 510      0.05
# 1                          11.3                 526      0.05
# 2                           2.0                 476       0.3
# 3                          12.1                 529       0.2
# 4                           6.4                 477       0.2
#
#    satisfaction_score  churned  monthly_fee   join_date
# 0                 2.0        0         7.99  21/03/2024
# 1                 3.0        0         0.00  08/10/2023
# 2                 3.0        0         7.99  04/05/2022
# 3                 5.0        1        12.99  16/12/2023
# ...

# %%
cols =['satisfaction_score','monthly_fee','skip_rate']
clean_waveMusic[cols] = clean_waveMusic[cols].apply(pd.to_numeric, errors='coerce')

# %%
clean_waveMusic.isna().sum()
# Out:
# user_id                          0
# country                          0
# age                              0
# gender                           0
# subscription_type                0
# avg_listening_hours_per_week     0
# total_songs_played               0
# skip_rate                        0
# satisfaction_score              44
# churned                          0
# monthly_fee                     33
# join_date                        0
# dtype: int64

# %%
clean_waveMusic['monthly_fee']= clean_waveMusic['monthly_fee'].fillna(clean_waveMusic['monthly_fee'].median())

# %%
clean_waveMusic['satisfaction_score']= clean_waveMusic['satisfaction_score'].fillna(clean_waveMusic['satisfaction_score'].mean())

# %%
clean_waveMusic.head()
# Out:
#   user_id  country  age  gender subscription_type  \
# 0   U1403    nepal   23  Female           Premium
# 1   U1165    nepal   63    Male           Student
# 2   U1474      usa   45  Female           Premium
# 3   U1478  nigeria   16  Female            Family
# 4   U1609    ghana   29    Male              Free
#
#    avg_listening_hours_per_week  total_songs_played  skip_rate  \
# 0                          11.5                 510       0.05
# 1                          11.3                 526       0.05
# 2                           2.0                 476       0.30
# 3                          12.1                 529       0.20
# 4                           6.4                 477       0.20
#
#    satisfaction_score  churned  monthly_fee   join_date
# 0                 2.0        0         7.99  21/03/2024
# 1                 3.0        0         0.00  08/10/2023
# 2                 3.0        0         7.99  04/05/2022
# ...

# %%
clean_waveMusic.isna().sum()
# Out:
# user_id                         0
# country                         0
# age                             0
# gender                          0
# subscription_type               0
# avg_listening_hours_per_week    0
# total_songs_played              0
# skip_rate                       0
# satisfaction_score              0
# churned                         0
# monthly_fee                     0
# join_date                       0
# dtype: int64

# %%
clean_waveMusic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 695 entries, 0 to 704
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   user_id                       695 non-null    object
#  1   country                       695 non-null    object
#  2   age                           695 non-null    int64
#  3   gender                        695 non-null    object
#  4   subscription_type             695 non-null    object
#  5   avg_listening_hours_per_week  695 non-null    float64
#  6   total_songs_played            695 non-null    int64
#  7   skip_rate                     695 non-null    float64
#  8   satisfaction_score            695 non-null    float64
#  9   churned                       695 non-null    int64
#  10  monthly_fee                   695 non-null    float64
#  11  join_date                     695 non-null    object
# dtypes: float64(4), int64(3), object(5)
# ...

# %%
clean_waveMusic['country'].unique()
# Out:
# array(['nepal', 'usa', 'nigeria', 'ghana', 'united kingdom', 'india',
#        'kenya', 'south africa', 'brazil'], dtype=object)

# %%
clean_waveMusic.to_csv("../data/DataWave_Music_cleaned.csv", index=False)
